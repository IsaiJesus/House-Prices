# %% [markdown]
# I have some concepts about Data Science and I know how to analyze and solve these problems with Machine Learning, but I'm still a beginner, thus I'm using ChatGPT as a resource to clarify doubts and understand concepts, in addition to complementing with videos and other online materials. This project is one of my first steps into the world of data science.

# %% [markdown]
# I started asking to ChatGPT what could be the structure to solve the problem, and it answered this structure.

# %% [markdown]
# # 1. Understanding Problem

# %% [markdown]
# Understainding what are the variables to know how to solve questions to solve all the problem.

# %% [markdown]
# The target variable is a continous number, so the solution could be done with regression or decision trees.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('./train.csv')

# %%
df_test = pd.read_csv('./test.csv')

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# I found a video solving the same problem using ChatGPT, In the video they use this code to create scrolleable tables with HTML.

# %%
from IPython.display import display, HTML

# %%
def create_scrolleable_table(df, table_id, title):
    html = f'<h3>{title}</h3>'
    html += f'<div id="{table_id}" style="height: 220px; overflow: auto;">'
    html += df.to_html()
    html += '</div>'
    return html

# %%
numerical_features = df_train.drop("Id", axis=1).select_dtypes(include=[np.number])
summary_stats = numerical_features.describe().T
html_numerical = create_scrolleable_table(summary_stats, 'numerical_features', 'Summary statistics for numerical features')

display(HTML(html_numerical))
# Out:
# <h3>Summary statistics for numerical features</h3><div id="numerical_features" style="height: 220px; overflow: auto;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>25%</th>
#       <th>50%</th>
#       <th>75%</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>MSSubClass</th>
#       <td>1460.0</td>
#       <td>56.897260</td>
#       <td>42.300571</td>
#       <td>20.0</td>
#       <td>20.00</td>
#       <td>50.0</td>
#       <td>70.00</td>
#       <td>190.0</td>
#     </tr>
#     <tr>
#       <th>LotFrontage</th>
#       <td>1201.0</td>
#       <td>70.049958</td>
#       <td>24.284752</td>
#       <td>21.0</td>
#       <td>59.00</td>
#       <td>69.0</td>
#       <td>80.00</td>
#       <td>313.0</td>
#     </tr>
#     <tr>
#       <th>LotArea</th>
#       <td>1460.0</td>
# ...

# %%
categorical_features = df_train.select_dtypes(include=[object])
cat_summary_stats = categorical_features.describe().T
html_categorical = create_scrolleable_table(cat_summary_stats, 'categorical_features', 'Summary statistics for categorical features')

display(HTML(html_categorical))
# Out:
# <h3>Summary statistics for categorical features</h3><div id="categorical_features" style="height: 220px; overflow: auto;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>unique</th>
#       <th>top</th>
#       <th>freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>MSZoning</th>
#       <td>1460</td>
#       <td>5</td>
#       <td>RL</td>
#       <td>1151</td>
#     </tr>
#     <tr>
#       <th>Street</th>
#       <td>1460</td>
#       <td>2</td>
#       <td>Pave</td>
#       <td>1454</td>
#     </tr>
#     <tr>
#       <th>Alley</th>
#       <td>91</td>
#       <td>2</td>
#       <td>Grvl</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>LotShape</th>
#       <td>1460</td>
#       <td>4</td>
#       <td>Reg</td>
#       <td>925</td>
#     </tr>
#     <tr>
#       <th>LandContour</th>
#       <td>1460</td>
#       <td>4</td>
#       <td>Lvl</td>
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df_train.shape
# Out:
# (1460, 81)

# %% [markdown]
# # 2. Exploratory Data Analysis (EDA) & Data Cleaning

# %% [markdown]
# ### Missing Data

# %%
count_missing_values = df_train.isnull().sum()

missing_values = count_missing_values.reset_index()
missing_values.columns = ['Column', 'Quantity']
missing_values = missing_values[missing_values['Quantity'] > 0]
missing_values = missing_values.sort_values(by='Quantity', ascending=False)

# %%
html_missing_values = create_scrolleable_table(missing_values, 'missing_values', 'Missing values')

display(HTML(html_missing_values))
# Out:
# <h3>Missing values</h3><div id="missing_values" style="height: 220px; overflow: auto;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Column</th>
#       <th>Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>72</th>
#       <td>PoolQC</td>
#       <td>1453</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>MiscFeature</td>
#       <td>1406</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Alley</td>
#       <td>1369</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>Fence</td>
#       <td>1179</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>MasVnrType</td>
#       <td>872</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>FireplaceQu</td>
#       <td>690</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>LotFrontage</td>
#       <td>259</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>GarageType</td>
#       <td>81</td>
# ...

# %%
# Delete values with more than 50% of the total data

total_rows = df_train.shape[0]

columns_to_delete = count_missing_values[count_missing_values > (total_rows * 0.5)].index

df_train = df_train.drop(columns=columns_to_delete)

# %%
df_train.shape
# Out:
# (1460, 76)

# %%
# Fill null number values with its mean 

columns_to_fill = count_missing_values[count_missing_values <= (total_rows * 0.5)].index
columns_to_fill = df_train[columns_to_fill].select_dtypes(include=['number']).columns

for col in columns_to_fill:
    mean = df_train[col].mean()
    df_train[col] = df_train[col].fillna(mean)

# %%
# Fill null object values with its top

count_missing_values = df_train.isnull().sum()

columns_to_fill = count_missing_values.index
columns_to_fill = df_train[columns_to_fill].select_dtypes(include=[object]).columns

for col in columns_to_fill:
    top_value = df_train[col].value_counts().idxmax()
    df_train[col] = df_train[col].fillna(top_value)

# %%
null_cols = df_train.isnull().any().sum()
print(f"Columnas con nulos: {null_cols}")
# Out:
# Columnas con nulos: 0

# %% [markdown]
# Before start with outliers, I'll confirm that there is no wrong data.

# %%
for col in df_train.drop(columns=['Id']).select_dtypes(include=[object]).columns:
    unique_values = df_train[col].unique()
    print(f"{col}: {unique_values}\n")
# Out:
# MSZoning: ['RL' 'RM' 'C (all)' 'FV' 'RH']
#
# Street: ['Pave' 'Grvl']
#
# LotShape: ['Reg' 'IR1' 'IR2' 'IR3']
#
# LandContour: ['Lvl' 'Bnk' 'Low' 'HLS']
#
# Utilities: ['AllPub' 'NoSeWa']
#
# LotConfig: ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
#
# LandSlope: ['Gtl' 'Mod' 'Sev']
#
# Neighborhood: ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
#
# Condition1: ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']
#
# Condition2: ['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN' 'PosA' 'RRAn' 'RRAe']
#
# BldgType: ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']
#
# HouseStyle: ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
#
# RoofStyle: ['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat' 'Shed']
#
# ...

# %% [markdown]
# All values seem correct, like values from the file *data_description.txt*.

# %%
df_train = df_train.drop(columns=['Id'])

# %% [markdown]
# ### Outliers

# %%
data = df_train['SalePrice']

fig, axes = plt.subplots(2, 1, figsize=(10, 6))

axes[0].hist(data, bins=40, edgecolor='black')
axes[0].set_title('Histogram of SalePrice')

axes[1].boxplot(data, vert=False)
axes[1].set_title('Boxplot of SalePrice')

plt.suptitle("Sale Price Analysis")

plt.show()

# %%
outliers = df_train[df_train['SalePrice'] > 500000]

html_outliers = create_scrolleable_table(outliers, 'outliers', 'Outliers')

display(HTML(html_outliers))
# Out:
# <h3>Outliers</h3><div id="outliers" style="height: 220px; overflow: auto;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSSubClass</th>
#       <th>MSZoning</th>
#       <th>LotFrontage</th>
#       <th>LotArea</th>
#       <th>Street</th>
#       <th>LotShape</th>
#       <th>LandContour</th>
#       <th>Utilities</th>
#       <th>LotConfig</th>
#       <th>LandSlope</th>
#       <th>Neighborhood</th>
#       <th>Condition1</th>
#       <th>Condition2</th>
#       <th>BldgType</th>
#       <th>HouseStyle</th>
#       <th>OverallQual</th>
#       <th>OverallCond</th>
#       <th>YearBuilt</th>
#       <th>YearRemodAdd</th>
#       <th>RoofStyle</th>
#       <th>RoofMatl</th>
#       <th>Exterior1st</th>
#       <th>Exterior2nd</th>
#       <th>MasVnrArea</th>
#       <th>ExterQual</th>
#       <th>ExterCond</th>
#       <th>Foundation</th>
#       <th>BsmtQual</th>
#       <th>BsmtCond</th>
# ...

# %% [markdown]
# Outliers make sense because of their features, so I won't delete them.

# %% [markdown]
# # 3. Preprocesing

# %% [markdown]
# ### Data transformation

# %% [markdown]
# At this point, I was thinking about transforming all the categorical values, but I didn't know what the best way to do it would be, so I asked ChatGPT how I could proceed and this is its answer.

# %% [markdown]
# ##### 1. Understand the `object` columns
# Answer key questions:
# - Does the column have too many unique values?
# - Is it a categorical column with few classes?
# - Are there errors or inconsistencies in the data?
#
# ##### 2. Decide what to do with each column
# 1. Remove irrelevant columns
# 2. Group categories
# 3. Correct inconsistencies
#
# ##### 3. Transform categorical columns
# 1. Label Encoding
# 2. One-Hot Encoding
# 3. Target Encoding (Advanced)
#
# ###### 4. Evaluate the impact of the transformations
# Once you have converted the `object` columns to numerical values, analyze the correlations with the target variable.

# %%
df_train.select_dtypes(object).columns
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional',
#        'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

def custom_features(df):
    df = df.copy()
    
    # Binary
    df['CentralAir'] = df['CentralAir'].map({
        'N': 0,
        'Y': 1
    }).astype(int)
    
    df['PavedDrive'] = df['PavedDrive'].map({
        'N': 0,
        'Y': 1,
        'P': 2
    }).astype(int)
    
    # Nominal
    nominal_features = [
        'MSZoning', 'Street', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope', 'Condition1', 'Condition2', 
        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'Foundation', 
        'BsmtFinType1', 'BsmtFinType2', 'Heating', 'Electrical', 'Functional', 'GarageType', 'GarageFinish', 
        'SaleType', 'SaleCondition'
    ]

    encoder = LabelEncoder()

    for n_feature in nominal_features:
        df[n_feature] = encoder.fit_transform(df[n_feature])
        
    freq_neighborhood = df['Neighborhood'].value_counts()    # Frecuency Encoding

    df['Neighborhood'] = df['Neighborhood'].map(freq_neighborhood)
    
    # Ordinal
    categorical_order = [['NoSeWa', 'AllPub']]    # Smallest to largest

    encoder = OrdinalEncoder(categories=categorical_order)

    df['Utilities'] = encoder.fit_transform(df[['Utilities']])
    
    ordinal_features = [
        'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'HeatingQC', 'KitchenQual', 
        'FireplaceQu', 'GarageQual', 'GarageCond'
    ]

    categorical_order = [['Po', 'Fa', 'TA', 'Gd',   'Ex']]

    encoder = OrdinalEncoder(categories=categorical_order)

    for o_feature in ordinal_features:
        df[o_feature] = encoder.fit_transform(df[[o_feature]])
    
    categorical_order = [['No', 'Av', 'Mn', 'Gd']]

    encoder = OrdinalEncoder(categories=categorical_order)

    df['BsmtExposure'] = encoder.fit_transform(df[['BsmtExposure']])

# %% [markdown]
# **Binary**

# %%
df_train['CentralAir'] = df_train['CentralAir'].map({
    'N': 0,
    'Y': 1
}).astype(int)

# %%
df_train['PavedDrive'] = df_train['PavedDrive'].map({
    'N': 0,
    'Y': 1,
    'P': 2
}).astype(int)

# %% [markdown]
# **Nominal**

# %%
from sklearn.preprocessing import LabelEncoder

nominal_features = [
    'MSZoning', 'Street', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope', 'Condition1', 'Condition2', 
    'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'Foundation', 
    'BsmtFinType1', 'BsmtFinType2', 'Heating', 'Electrical', 'Functional', 'GarageType', 'GarageFinish', 
    'SaleType', 'SaleCondition'
]

encoder = LabelEncoder()

for n_feature in nominal_features:
    df_train[n_feature] = encoder.fit_transform(df_train[n_feature])

# %%
# Frequency encoding

freq_neighborhood = df_train['Neighborhood'].value_counts()

df_train['Neighborhood'] = df_train['Neighborhood'].map(freq_neighborhood)

# %% [markdown]
# **Ordinal**

# %% [markdown]
# For ordinal values, I looked for a way to transform these columns with an order.

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
# Smallest to largest
categorical_order = [['NoSeWa', 'AllPub']]

encoder = OrdinalEncoder(categories=categorical_order)

df_train['Utilities'] = encoder.fit_transform(df_train[['Utilities']])

# %%
ordinal_features = [
    'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'HeatingQC', 'KitchenQual', 
    'FireplaceQu', 'GarageQual', 'GarageCond'
]

categorical_order = [['Po', 'Fa', 'TA', 'Gd',   'Ex']]

encoder = OrdinalEncoder(categories=categorical_order)

for o_feature in ordinal_features:
    df_train[o_feature] = encoder.fit_transform(df_train[[o_feature]])

# %%
categorical_order = [['No', 'Av', 'Mn', 'Gd']]

encoder = OrdinalEncoder(categories=categorical_order)

df_train['BsmtExposure'] = encoder.fit_transform(df_train[['BsmtExposure']])

# %% [markdown]
# ---

# %%
object_columns = df_train.select_dtypes(include='object')

print(f"Object columns: {object_columns.shape[1]}")
# Out:
# Object columns: 0

# %%
transformed_features = df_train.head()
html_transformed_features = create_scrolleable_table(transformed_features, 'transformed_features', 'Transformed features')

display(HTML(html_transformed_features))
# Out:
# <h3>Transformed features</h3><div id="transformed_features" style="height: 220px; overflow: auto;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSSubClass</th>
#       <th>MSZoning</th>
#       <th>LotFrontage</th>
#       <th>LotArea</th>
#       <th>Street</th>
#       <th>LotShape</th>
#       <th>LandContour</th>
#       <th>Utilities</th>
#       <th>LotConfig</th>
#       <th>LandSlope</th>
#       <th>Neighborhood</th>
#       <th>Condition1</th>
#       <th>Condition2</th>
#       <th>BldgType</th>
#       <th>HouseStyle</th>
#       <th>OverallQual</th>
#       <th>OverallCond</th>
#       <th>YearBuilt</th>
#       <th>YearRemodAdd</th>
#       <th>RoofStyle</th>
#       <th>RoofMatl</th>
#       <th>Exterior1st</th>
#       <th>Exterior2nd</th>
#       <th>MasVnrArea</th>
#       <th>ExterQual</th>
#       <th>ExterCond</th>
#       <th>Foundation</th>
#       <th>BsmtQual</th>
# ...

# %% [markdown]
# # 4. Feature Engineering

# %% [markdown]
# ### 1. Create new features

# %%
# Total Square Footage

df_train['TotalSF'] = df_train['TotalBsmtSF'] + df_train['1stFlrSF'] + df_train['2ndFlrSF']

# %%
# Quality-to-Price Ratio

df_train['QualityPriceRatio'] = df_train['OverallQual'] / df_train['SalePrice']

# %%
# House Age

df_train['HouseAge'] = df_train['YrSold'] - df_train['YearBuilt']

# %%
# Time Since Last Remodel

df_train['SinceRemodel'] = df_train['YrSold'] - df_train['YearRemodAdd']

# %% [markdown]
# ### 2. Generate Binary Features

# %%
# Does it have a basement, garage, or pool?

df_train['HasBsmt'] = (df_train['TotalBsmtSF'] > 0).astype(int)
df_train['HasGarage'] = (df_train['GarageArea'] > 0).astype(int)
df_train['HasPool'] = (df_train['PoolArea'] > 0).astype(int)

# %% [markdown]
# ### Correlations

# %%
corr = df_train.corr()['SalePrice'].drop('SalePrice')

# High positive correlations
positive_corr = corr[corr > 0.6].sort_values(ascending=False)
print("Variables with high positive correlation:")
print(positive_corr, '\n')

# High negative correlations
negative_corr = corr[corr < -0.6].sort_values(ascending=False)
print("Variables with high negative correlation:")
print(negative_corr)
# Out:
# Variables with high positive correlation:
# OverallQual    0.790982
# TotalSF        0.782260
# GrLivArea      0.708624
# ExterQual      0.682639
# KitchenQual    0.659600
# BsmtQual       0.650138
# GarageCars     0.640409
# GarageArea     0.623431
# TotalBsmtSF    0.613581
# 1stFlrSF       0.605852
# Name: SalePrice, dtype: float64
#
# Variables with high negative correlation:
# QualityPriceRatio   -0.707021
# Name: SalePrice, dtype: float64

# %% [markdown]
# ### 7. Validate Your New Features

# %%
new_features = df_train.head()
html_new_features = create_scrolleable_table(new_features, 'transformed_features', 'Transformed features')

display(HTML(html_new_features))
# Out:
# <h3>Transformed features</h3><div id="transformed_features" style="height: 220px; overflow: auto;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSSubClass</th>
#       <th>MSZoning</th>
#       <th>LotFrontage</th>
#       <th>LotArea</th>
#       <th>Street</th>
#       <th>LotShape</th>
#       <th>LandContour</th>
#       <th>Utilities</th>
#       <th>LotConfig</th>
#       <th>LandSlope</th>
#       <th>Neighborhood</th>
#       <th>Condition1</th>
#       <th>Condition2</th>
#       <th>BldgType</th>
#       <th>HouseStyle</th>
#       <th>OverallQual</th>
#       <th>OverallCond</th>
#       <th>YearBuilt</th>
#       <th>YearRemodAdd</th>
#       <th>RoofStyle</th>
#       <th>RoofMatl</th>
#       <th>Exterior1st</th>
#       <th>Exterior2nd</th>
#       <th>MasVnrArea</th>
#       <th>ExterQual</th>
#       <th>ExterCond</th>
#       <th>Foundation</th>
#       <th>BsmtQual</th>
# ...

# %%
features = positive_corr.index.tolist() + negative_corr.index.tolist()
y = 'SalePrice'

n_rows = (len(features) + 1) // 2
fig, axes = plt.subplots(n_rows, 2, figsize=(10, n_rows * 3), sharey=True)
axes = axes.flatten()

for i, feature in enumerate(features):
    axes[i].scatter(df_train[feature], df_train[y], alpha=0.7)
    axes[i].set_title(f'{feature} vs {y}')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel(y)

for i in range(len(features), len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()

# %%
y = 'SalePrice'

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 8))

ax1.scatter(df_train['SaleType'], df_train[y])
ax1.set_title(f'SaleType vs {y}')
ax1.set_xlabel('SaleType')
ax1.set_ylabel(y)

ax2.scatter(df_train['SaleCondition'], df_train[y])
ax2.set_title(f'SaleCondition vs {y}')
ax2.set_xlabel('SaleCondition')
ax2.set_ylabel(y)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Models

# %% [markdown]
# 1. Linear Regression
# 2. Lasso Regression
# 3. Decision Tree Classifier
# 4. Random Forest
# 5. XGBoost

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 6. Model Evaluation

# %% [markdown]
# # 7. Optimization
